# %% [markdown]
# # 전국 내국인 카드 소비 데이터

# %%
# !pip install chardet

# %%
import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/20240623191500__202306-202405_데이터랩_다운로드/20240623191500_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/20240623191500__202306-202405_데이터랩_다운로드/20240623191500_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        기준년월 광역지자체     대분류           지출액       전년도 지출액
# 0    202306    전국   관광총소비  3.569349e+09  3.625228e+09
# 1    202307    전국   관광총소비  3.589248e+09  3.698978e+09
# 2    202308    전국   관광총소비  3.506755e+09  3.630009e+09
# 3    202309    전국   관광총소비  3.456150e+09  3.454181e+09
# 4    202310    전국   관광총소비  3.672830e+09  3.858734e+09
# ..      ...   ...     ...           ...           ...
# 236  202405    전국      콘도  1.650840e+07  1.926138e+07
# 237  202405    전국    육상운송  9.951574e+07  1.021204e+08
# 238  202405    전국  캠핑장/펜션  1.060080e+06  1.024255e+06
# 239  202405    전국    수상운송  8.297516e+06  9.415817e+06
# 240  202405    전국     스키장  1.330370e+05  5.484660e+05
#
# [241 rows x 5 columns]

# %%
import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/20240623191500__202306-202405_데이터랩_다운로드/20240623191500_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/20240623191500__202306-202405_데이터랩_다운로드/20240623191500_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#       광역지자체           소비액      전년동기 소비액  전년대비 소비증감률
# 0     서울특별시  1.218184e+10  1.261937e+10        -3.5
# 1     부산광역시  3.174030e+09  3.206206e+09        -1.0
# 2     대구광역시  1.910465e+09  1.910324e+09         0.0
# 3     인천광역시  2.026372e+09  1.945447e+09         4.2
# 4     광주광역시  9.402452e+08  9.784635e+08        -3.9
# 5     대전광역시  1.673854e+09  1.657862e+09         1.0
# 6     울산광역시  5.663395e+08  5.829680e+08        -2.9
# 7   세종특별자치시  1.035879e+08  1.050803e+08        -1.4
# 8       경기도  9.549898e+09  9.770983e+09        -2.3
# 9      충청북도  1.043422e+09  1.085256e+09        -3.9
# 10     충청남도  1.202400e+09  1.232619e+09        -2.5
# 11     전라남도  9.854088e+08  1.011227e+09        -2.6
# 12     경상북도  1.266041e+09  1.311369e+09        -3.5
# 13     경상남도  1.561888e+09  1.599574e+09        -2.4
# 14  제주특별자치도  1.000704e+09  1.190406e+09       -15.9
# 15  강원특별자치도  1.297813e+09  1.397463e+09        -7.1
# ...

# %%
import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/20240623191500__202306-202405_데이터랩_다운로드/20240623191500_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/20240623191500__202306-202405_데이터랩_다운로드/20240623191500_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류       대분류 지출액  대분류 지출액 비율       중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  1.282373e+10        31.1  8.939098e+07         0.7
# 1      쇼핑업   대형쇼핑몰  1.282373e+10        31.1  1.027297e+10        80.1
# 2      쇼핑업  레저용품쇼핑  1.282373e+10        31.1  1.916168e+09        14.9
# 3      쇼핑업     면세점  1.282373e+10        31.1  5.451996e+08         4.3
# 4      숙박업    기타숙박  1.534206e+09         3.7  7.177254e+08        46.8
# 5      숙박업  캠핑장/펜션  1.534206e+09         3.7  1.191420e+07         0.8
# 6      숙박업      콘도  1.534206e+09         3.7  2.455438e+08        16.0
# 7      숙박업      호텔  1.534206e+09         3.7  5.590229e+08        36.4
# 8     식음료업     식음료  2.175366e+10        52.8  2.175366e+10       100.0
# 9   여가서비스업     골프장  2.920459e+09         7.1  2.018239e+09        69.1
# 10  여가서비스업  관광유원시설  2.920459e+09         7.1  1.326563e+08         4.5
# ...

# %%
import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/20240623191500__202306-202405_데이터랩_다운로드/20240623191500_지역별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/20240623191500__202306-202405_데이터랩_다운로드/20240623191500_지역별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#         광역지자체 명     기초지자체 명     광역지자체 지출액  광역지자체 지출액 비율    기초지자체 지출액  \
# 0    기타(지역 미분류)  기타(지역 미분류)  1.884476e+07           0.0   18844765.0
# 1       강원특별자치도         강릉시  1.297813e+09           3.1  205263120.0
# 2       강원특별자치도         고성군  1.297813e+09           3.1   51795409.0
# 3       강원특별자치도         동해시  1.297813e+09           3.1   46320919.0
# 4       강원특별자치도         삼척시  1.297813e+09           3.1   56785180.0
# ..          ...         ...           ...           ...          ...
# 249        충청북도     청주시 상당구  1.043422e+09           2.5  120971209.0
# 250        충청북도     청주시 서원구  1.043422e+09           2.5  114741778.0
# 251        충청북도     청주시 청원구  1.043422e+09           2.5  123836602.0
# 252        충청북도     청주시 흥덕구  1.043422e+09           2.5  219242048.0
# 253        충청북도         충주시  1.043422e+09           2.5  140418355.0
#
#      기초지자체 지출액 비율
# 0           100.0
# 1            15.8
# ...

# %% [markdown]
# # 서울 내국인 관광지출액(BC+신한)

# %%
# 서울 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193244_서울특별시_202306-202405_데이터랩_다운로드/20240623193244_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193244_서울특별시_202306-202405_데이터랩_다운로드/20240623193244_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        기준년월  광역지자체     중분류           지출액       전년도 지출액
# 0    202306  서울특별시   관광총소비  1.061383e+09  1.071049e+09
# 1    202307  서울특별시   관광총소비  1.070818e+09  1.080624e+09
# 2    202308  서울특별시   관광총소비  1.006149e+09  1.024933e+09
# 3    202309  서울특별시   관광총소비  1.001844e+09  1.008496e+09
# 4    202310  서울특별시   관광총소비  1.032694e+09  1.091163e+09
# ..      ...    ...     ...           ...           ...
# 235  202405  서울특별시    육상운송  3.244397e+07  3.280744e+07
# 236  202405  서울특별시  캠핑장/펜션  7.797000e+03  9.930000e+03
# 237  202405  서울특별시    수상운송  5.910717e+06  7.166940e+06
# 238  202405  서울특별시     스키장  0.000000e+00  1.511590e+05
# 239  202311  서울특별시      콘도  9.333400e+04  9.219500e+04
#
# [240 rows x 5 columns]

# %%
# 서울 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193244_서울특별시_202306-202405_데이터랩_다운로드/20240623193244_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193244_서울특별시_202306-202405_데이터랩_다운로드/20240623193244_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0  서울특별시  1.218184e+10  1.261937e+10         0.0

# %%
# 서울 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193244_서울특별시_202306-202405_데이터랩_다운로드/20240623193244_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193244_서울특별시_202306-202405_데이터랩_다운로드/20240623193244_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류       대분류 지출액  대분류 지출액 비율       중분류 지출액  중분류 지출액 비율
# 0      쇼핑업     면세점  3.636363e+09        29.9  1.340226e+08       100.0
# 1      쇼핑업   관광기념품  3.636363e+09        29.9  1.605414e+07       100.0
# 2      쇼핑업  레저용품쇼핑  3.636363e+09        29.9  4.401702e+08       100.0
# 3      쇼핑업   대형쇼핑몰  3.636363e+09        29.9  3.046116e+09       100.0
# 4      숙박업      호텔  3.785258e+08         3.1  2.471259e+08       100.0
# 5      숙박업    기타숙박  3.785258e+08         3.1  1.281374e+08       100.0
# 6      숙박업      콘도  3.785258e+08         3.1  3.163468e+06       100.0
# 7      숙박업  캠핑장/펜션  3.785258e+08         3.1  9.895800e+04       100.0
# 8     식음료업     식음료  6.613468e+09        54.3  6.613468e+09       100.0
# 9   여가서비스업  관광유원시설  4.240590e+08         3.5  3.600568e+07       100.0
# 10  여가서비스업     골프장  4.240590e+08         3.5  1.175060e+08       100.0
# ...

# %% [markdown]
# # 부산 내국인 관광지출액(BC+신한)

# %%
# 부산 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193320_부산광역시_202306-202405_데이터랩_다운로드/20240623193320_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193320_부산광역시_202306-202405_데이터랩_다운로드/20240623193320_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.7036104114189756, 'language': 'Korean'}
#        기준년월  광역지자체    중분류          지출액      전년도 지출액
# 0    202306  부산광역시  관광총소비  262734446.0  268357090.0
# 1    202307  부산광역시  관광총소비  268419454.0  278869247.0
# 2    202308  부산광역시  관광총소비  268179140.0  276664926.0
# 3    202309  부산광역시  관광총소비  261699768.0  255525444.0
# 4    202310  부산광역시  관광총소비  278166558.0  284652094.0
# ..      ...    ...    ...          ...          ...
# 223  202401  부산광역시   육상운송       4933.0       9325.0
# 224  202402  부산광역시   육상운송      11084.0      18768.0
# 225  202403  부산광역시   육상운송       3712.0      16384.0
# 226  202404  부산광역시   육상운송       3878.0      20692.0
# 227  202405  부산광역시   육상운송       7552.0      21500.0
#
# [228 rows x 5 columns]

# %%
# 부산 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193320_부산광역시_202306-202405_데이터랩_다운로드/20240623193320_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193320_부산광역시_202306-202405_데이터랩_다운로드/20240623193320_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0  부산광역시  3.174030e+09  3.206206e+09         0.0

# %%
# 부산 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193320_부산광역시_202306-202405_데이터랩_다운로드/20240623193320_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193320_부산광역시_202306-202405_데이터랩_다운로드/20240623193320_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류       대분류 지출액  대분류 지출액 비율       중분류 지출액  중분류 지출액 비율
# 0      쇼핑업     면세점  1.274124e+09        40.1  3.112644e+07       100.0
# 1      쇼핑업   관광기념품  1.274124e+09        40.1  4.217134e+06       100.0
# 2      쇼핑업  레저용품쇼핑  1.274124e+09        40.1  9.176049e+07       100.0
# 3      쇼핑업   대형쇼핑몰  1.274124e+09        40.1  1.147020e+09       100.0
# 4      숙박업      호텔  1.214058e+08         3.8  6.146709e+07       100.0
# 5      숙박업      콘도  1.214058e+08         3.8  5.597865e+06       100.0
# 6      숙박업    기타숙박  1.214058e+08         3.8  5.423851e+07       100.0
# 7      숙박업  캠핑장/펜션  1.214058e+08         3.8  1.023680e+05       100.0
# 8     식음료업     식음료  1.587145e+09        50.0  1.587145e+09       100.0
# 9   여가서비스업     골프장  1.125893e+08         3.5  6.382332e+07       100.0
# 10  여가서비스업    기타레저  1.125893e+08         3.5  2.512168e+07       100.0
# ...

# %% [markdown]
# # 대구 내국인 관광지출액(BC+신한)

# %%
# 대구 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193330_대구광역시_202306-202405_데이터랩_다운로드/20240623193330_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193330_대구광역시_202306-202405_데이터랩_다운로드/20240623193330_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.6938083121289228, 'language': 'Korean'}
#        기준년월  광역지자체    중분류          지출액      전년도 지출액
# 0    202306  대구광역시  관광총소비  161620704.0  159790490.0
# 1    202307  대구광역시  관광총소비  160671850.0  155350743.0
# 2    202308  대구광역시  관광총소비  151204898.0  147876448.0
# 3    202309  대구광역시  관광총소비  157564249.0  152903322.0
# 4    202310  대구광역시  관광총소비  167238481.0  171941219.0
# ..      ...    ...    ...          ...          ...
# 219  202404  대구광역시     콘도       1440.0       5332.0
# 220  202404  대구광역시   육상운송        224.0          0.0
# 221  202405  대구광역시     콘도         70.0         80.0
# 222  202405  대구광역시    스키장          0.0         80.0
# 223  202405  대구광역시   육상운송         28.0       5000.0
#
# [224 rows x 5 columns]

# %%
# 대구 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193330_대구광역시_202306-202405_데이터랩_다운로드/20240623193330_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193330_대구광역시_202306-202405_데이터랩_다운로드/20240623193330_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0  대구광역시  1.910465e+09  1.910324e+09         0.0

# %%
# 대구 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193330_대구광역시_202306-202405_데이터랩_다운로드/20240623193330_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193330_대구광역시_202306-202405_데이터랩_다운로드/20240623193330_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업     면세점  865714007.0        45.3    3003619.0       100.0
# 1      쇼핑업   관광기념품  865714007.0        45.3    1964846.0       100.0
# 2      쇼핑업  레저용품쇼핑  865714007.0        45.3   93889135.0       100.0
# 3      쇼핑업   대형쇼핑몰  865714007.0        45.3  766856407.0       100.0
# 4      숙박업      호텔   40912438.0         2.1   17407672.0       100.0
# 5      숙박업    기타숙박   40912438.0         2.1   23461467.0       100.0
# 6      숙박업  캠핑장/펜션   40912438.0         2.1      24207.0       100.0
# 7      숙박업      콘도   40912438.0         2.1      19091.0       100.0
# 8     식음료업     식음료  867745202.0        45.4  867745202.0       100.0
# 9   여가서비스업  관광유원시설   81829469.0         4.3    4143754.0       100.0
# 10  여가서비스업     골프장   81829469.0         4.3   48084399.0       100.0
# 11  여가서비스업    기타레저   81829469.0         4.3   20286297.0       100.0
# ...

# %% [markdown]
# # 인천 내국인 관광지출액(BC+신한)

# %%
# 인천 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193340_인천광역시_202306-202405_데이터랩_다운로드/20240623193340_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193340_인천광역시_202306-202405_데이터랩_다운로드/20240623193340_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.7036104114189756, 'language': 'Korean'}
#        기준년월  광역지자체    중분류          지출액      전년도 지출액
# 0    202306  인천광역시  관광총소비  172815936.0  149840385.0
# 1    202307  인천광역시  관광총소비  174388449.0  162417124.0
# 2    202308  인천광역시  관광총소비  167263948.0  160222866.0
# 3    202309  인천광역시  관광총소비  168310476.0  159736131.0
# 4    202310  인천광역시  관광총소비  176363286.0  173889891.0
# ..      ...    ...    ...          ...          ...
# 223  202405  인천광역시    골프장    7679602.0    7528189.0
# 224  202405  인천광역시   기타레저    1497356.0    1307136.0
# 225  202405  인천광역시  문화서비스    1159041.0    1229321.0
# 226  202405  인천광역시    식음료   95770868.0   97197101.0
# 227  202405  인천광역시   육상운송      63765.0      62449.0
#
# [228 rows x 5 columns]

# %%
# 인천 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193340_인천광역시_202306-202405_데이터랩_다운로드/20240623193340_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193340_인천광역시_202306-202405_데이터랩_다운로드/20240623193340_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0  인천광역시  2.026372e+09  1.945447e+09         0.0

# %%
# 인천 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193340_인천광역시_202306-202405_데이터랩_다운로드/20240623193340_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193340_인천광역시_202306-202405_데이터랩_다운로드/20240623193340_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류       대분류 지출액  대분류 지출액 비율       중분류 지출액  중분류 지출액 비율
# 0      쇼핑업     면세점  7.133873e+08        35.2  2.079132e+08       100.0
# 1      쇼핑업   관광기념품  7.133873e+08        35.2  1.856134e+06       100.0
# 2      쇼핑업  레저용품쇼핑  7.133873e+08        35.2  1.100456e+08       100.0
# 3      쇼핑업   대형쇼핑몰  7.133873e+08        35.2  3.935725e+08       100.0
# 4      숙박업      호텔  7.358126e+07         3.6  4.161910e+07       100.0
# 5      숙박업      콘도  7.358126e+07         3.6  1.154053e+06       100.0
# 6      숙박업  캠핑장/펜션  7.358126e+07         3.6  7.734140e+05       100.0
# 7      숙박업    기타숙박  7.358126e+07         3.6  3.003470e+07       100.0
# 8     식음료업     식음료  1.101235e+09        54.3  1.101235e+09       100.0
# 9   여가서비스업  관광유원시설  1.053813e+08         5.2  4.437480e+06       100.0
# 10  여가서비스업     골프장  1.053813e+08         5.2  7.258415e+07       100.0
# ...

# %% [markdown]
# # 광주 내국인 관광지출액(BC+신한)

# %%
# 광주 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193349_광주광역시_202306-202405_데이터랩_다운로드/20240623193349_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193349_광주광역시_202306-202405_데이터랩_다운로드/20240623193349_관광소비 추이.csv', encoding='EUC-KR')

# 데이터 확인
data
# Out:
# {'encoding': 'GB2312', 'confidence': 0.49074074074074076, 'language': 'Chinese'}
#        기준년월  광역지자체     중분류         지출액     전년도 지출액
# 0    202306  광주광역시   관광총소비  79273453.0  87299314.0
# 1    202307  광주광역시   관광총소비  78514682.0  81496020.0
# 2    202308  광주광역시   관광총소비  74034404.0  76407751.0
# 3    202309  광주광역시   관광총소비  77121995.0  79731260.0
# 4    202310  광주광역시   관광총소비  83646103.0  89338133.0
# ..      ...    ...     ...         ...         ...
# 181  202405  광주광역시     식음료  43141489.0  45941412.0
# 182  202405  광주광역시    육상운송     15334.0     10153.0
# 183  202405  광주광역시     렌터카     24706.0     30876.0
# 184  202404  광주광역시  캠핑장/펜션       175.0         0.0
# 185  202405  광주광역시  캠핑장/펜션      2104.0         0.0
#
# [186 rows x 5 columns]

# %%
# 광주 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193349_광주광역시_202306-202405_데이터랩_다운로드/20240623193349_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('//content/drive/MyDrive/문체부 공모전/20240623193349_광주광역시_202306-202405_데이터랩_다운로드/20240623193349_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명          소비액     전년동기 소비액  전년대비 소비증감률
# 0  광주광역시  940245178.0  978463535.0         0.0

# %%
# 광주 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193349_광주광역시_202306-202405_데이터랩_다운로드/20240623193349_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193349_광주광역시_202306-202405_데이터랩_다운로드/20240623193349_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  374482998.0        39.8    1176625.0       100.0
# 1      쇼핑업  레저용품쇼핑  374482998.0        39.8   62483644.0       100.0
# 2      쇼핑업   대형쇼핑몰  374482998.0        39.8  310822729.0       100.0
# 3      숙박업      호텔   16294715.0         1.7    1186485.0       100.0
# 4      숙박업    기타숙박   16294715.0         1.7   15104610.0       100.0
# 5      숙박업  캠핑장/펜션   16294715.0         1.7       3620.0       100.0
# 6     식음료업     식음료  509121644.0        54.1  509121644.0       100.0
# 7   여가서비스업  관광유원시설   39058039.0         4.2    2369738.0       100.0
# 8   여가서비스업     골프장   39058039.0         4.2   24157050.0       100.0
# 9   여가서비스업    기타레저   39058039.0         4.2    6615759.0       100.0
# 10  여가서비스업   문화서비스   39058039.0         4.2    5915492.0       100.0
# 11     여행업     여행업     775632.0         0.1     775632.0       100.0
# ...

# %% [markdown]
# # 대전 내국인 관광지출액(BC+신한)

# %%
# 대전 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193358_대전광역시_202306-202405_데이터랩_다운로드/20240623193358_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193358_대전광역시_202306-202405_데이터랩_다운로드/20240623193358_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.6675627240143369, 'language': 'Korean'}
#        기준년월  광역지자체    중분류          지출액      전년도 지출액
# 0    202306  대전광역시  관광총소비  138415311.0  133744089.0
# 1    202307  대전광역시  관광총소비  144922005.0  132974485.0
# 2    202308  대전광역시  관광총소비  140874243.0  138540833.0
# 3    202309  대전광역시  관광총소비  150825878.0  136586317.0
# 4    202310  대전광역시  관광총소비  150875285.0  138589090.0
# ..      ...    ...    ...          ...          ...
# 198  202308  대전광역시    여행업      19623.0       2228.0
# 199  202309  대전광역시    여행업      24614.0       6394.0
# 200  202312  대전광역시   수상운송        206.0        410.0
# 201  202401  대전광역시    여행업      17920.0       9234.0
# 202  202404  대전광역시   수상운송          1.0        870.0
#
# [203 rows x 5 columns]

# %%
# 대전 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193358_대전광역시_202306-202405_데이터랩_다운로드/20240623193358_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193358_대전광역시_202306-202405_데이터랩_다운로드/20240623193358_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0  대전광역시  1.673854e+09  1.657862e+09         0.0

# %%
# 대전 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193358_대전광역시_202306-202405_데이터랩_다운로드/20240623193358_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193358_대전광역시_202306-202405_데이터랩_다운로드/20240623193358_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  466145290.0        27.8    1053199.0       100.0
# 1      쇼핑업  레저용품쇼핑  466145290.0        27.8   36757839.0       100.0
# 2      쇼핑업   대형쇼핑몰  466145290.0        27.8  428334252.0       100.0
# 3      숙박업      호텔   20508401.0         1.2    7113435.0       100.0
# 4      숙박업  캠핑장/펜션   20508401.0         1.2       9871.0       100.0
# 5      숙박업    기타숙박   20508401.0         1.2   13382080.0       100.0
# 6      숙박업      콘도   20508401.0         1.2       3015.0       100.0
# 7     식음료업     식음료  500898497.0        29.9  500898497.0       100.0
# 8   여가서비스업  관광유원시설   26463256.0         1.6    2010388.0       100.0
# 9   여가서비스업     골프장   26463256.0         1.6   14338909.0       100.0
# 10  여가서비스업    기타레저   26463256.0         1.6    4584127.0       100.0
# 11  여가서비스업   문화서비스   26463256.0         1.6    5529832.0       100.0
# ...

# %% [markdown]
# # 울산 내국인 관광지출액(BC+신한)

# %%
# 울산 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193409_울산광역시_202306-202405_데이터랩_다운로드/20240623193409_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193409_울산광역시_202306-202405_데이터랩_다운로드/20240623193409_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.6693262411347518, 'language': 'Korean'}
#        기준년월  광역지자체    중분류         지출액     전년도 지출액
# 0    202306  울산광역시  관광총소비  48349979.0  48582896.0
# 1    202307  울산광역시  관광총소비  49623213.0  50690243.0
# 2    202308  울산광역시  관광총소비  47055278.0  49977120.0
# 3    202309  울산광역시  관광총소비  46535776.0  46542028.0
# 4    202310  울산광역시  관광총소비  48896910.0  53169108.0
# ..      ...    ...    ...         ...         ...
# 202  202403  울산광역시    여행업      8027.0     26167.0
# 203  202403  울산광역시    면세점         0.0       200.0
# 204  202404  울산광역시    여행업      6419.0     11483.0
# 205  202405  울산광역시    여행업      7141.0      8736.0
# 206  202405  울산광역시    면세점         0.0      2084.0
#
# [207 rows x 5 columns]

# %%
# 울산 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193409_울산광역시_202306-202405_데이터랩_다운로드/20240623193409_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193409_울산광역시_202306-202405_데이터랩_다운로드/20240623193409_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명          소비액     전년동기 소비액  전년대비 소비증감률
# 0  울산광역시  566339543.0  582968046.0         0.0

# %%
# 울산 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193409_울산광역시_202306-202405_데이터랩_다운로드/20240623193409_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193409_울산광역시_202306-202405_데이터랩_다운로드/20240623193409_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  143652256.0        25.4     587458.0       100.0
# 1      쇼핑업  레저용품쇼핑  143652256.0        25.4   33057937.0       100.0
# 2      쇼핑업   대형쇼핑몰  143652256.0        25.4  110004996.0       100.0
# 3      쇼핑업     면세점  143652256.0        25.4       1865.0       100.0
# 4      숙박업    기타숙박   17548940.0         3.1   12861857.0       100.0
# 5      숙박업      호텔   17548940.0         3.1    4549483.0       100.0
# 6      숙박업  캠핑장/펜션   17548940.0         3.1     118870.0       100.0
# 7      숙박업      콘도   17548940.0         3.1      18730.0       100.0
# 8     식음료업     식음료  363305962.0        64.1  363305962.0       100.0
# 9   여가서비스업  관광유원시설   41261817.0         7.3     422384.0       100.0
# 10  여가서비스업     골프장   41261817.0         7.3   32280985.0       100.0
# 11  여가서비스업    기타레저   41261817.0         7.3    4964229.0       100.0
# ...

# %% [markdown]
# # 세종 내국인 관광지출액(BC+신한)

# %%
# 세종 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193426_세종특별자치시_202306-202405_데이터랩_다운로드/20240623193426_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193426_세종특별자치시_202306-202405_데이터랩_다운로드/20240623193426_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        기준년월    광역지자체    중분류        지출액    전년도 지출액
# 0    202306  세종특별자치시  관광총소비  9635570.0  9154265.0
# 1    202307  세종특별자치시  관광총소비  8746597.0  9122580.0
# 2    202308  세종특별자치시  관광총소비  8495642.0  8767942.0
# 3    202309  세종특별자치시  관광총소비  8834551.0  8660693.0
# 4    202310  세종특별자치시  관광총소비  9122906.0  9472475.0
# ..      ...      ...    ...        ...        ...
# 158  202404  세종특별자치시   육상운송      365.0      587.0
# 159  202404  세종특별자치시    렌터카     1105.0     3504.0
# 160  202405  세종특별자치시    여행업     2200.0     1580.0
# 161  202405  세종특별자치시   육상운송      911.0      495.0
# 162  202405  세종특별자치시    렌터카      841.0     1067.0
#
# [163 rows x 5 columns]

# %%
# 세종 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193426_세종특별자치시_202306-202405_데이터랩_다운로드/20240623193426_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193426_세종특별자치시_202306-202405_데이터랩_다운로드/20240623193426_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#     광역지자체명          소비액     전년동기 소비액  전년대비 소비증감률
# 0  세종특별자치시  103587910.0  105080321.0         0.0

# %%
# 세종 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193426_세종특별자치시_202306-202405_데이터랩_다운로드/20240623193426_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193426_세종특별자치시_202306-202405_데이터랩_다운로드/20240623193426_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류     대분류 지출액  대분류 지출액 비율     중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  16725848.0        16.1     50557.0       100.0
# 1      쇼핑업  레저용품쇼핑  16725848.0        16.1   5625968.0       100.0
# 2      쇼핑업   대형쇼핑몰  16725848.0        16.1  11049323.0       100.0
# 3      숙박업  캠핑장/펜션   2871483.0         2.8     13480.0       100.0
# 4      숙박업    기타숙박   2871483.0         2.8   2858004.0       100.0
# 5     식음료업     식음료  70976708.0        68.5  70976708.0       100.0
# 6   여가서비스업  관광유원시설  12990206.0        12.5    143670.0       100.0
# 7   여가서비스업     골프장  12990206.0        12.5   9957083.0       100.0
# 8   여가서비스업    기타레저  12990206.0        12.5   1690963.0       100.0
# 9   여가서비스업   문화서비스  12990206.0        12.5   1198490.0       100.0
# 10     여행업     여행업      4783.0         0.0      4783.0       100.0
# 11     운송업    육상운송     18880.0         0.0      8529.0       100.0
# ...

# %% [markdown]
# # 경기 내국인 관광지출액(BC+신한)

# %%
# 경기 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193445_경기도_202306-202405_데이터랩_다운로드/20240623193445_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193445_경기도_202306-202405_데이터랩_다운로드/20240623193445_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        기준년월 광역지자체    중분류          지출액      전년도 지출액
# 0    202306   경기도  관광총소비  828705136.0  836927892.0
# 1    202307   경기도  관광총소비  831045286.0  856070784.0
# 2    202308   경기도  관광총소비  789085425.0  810800109.0
# 3    202309   경기도  관광총소비  808696228.0  822325466.0
# 4    202310   경기도  관광총소비  868695077.0  918034086.0
# ..      ...   ...    ...          ...          ...
# 235  202307   경기도   항공운송        780.0          0.0
# 236  202308   경기도   항공운송       1000.0          0.0
# 237  202309   경기도   항공운송       1500.0          0.0
# 238  202310   경기도   항공운송       1295.0          0.0
# 239  202311   경기도   항공운송          0.0          0.0
#
# [240 rows x 5 columns]

# %%
# 경기 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193445_경기도_202306-202405_데이터랩_다운로드/20240623193445_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193445_경기도_202306-202405_데이터랩_다운로드/20240623193445_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0    경기도  9.549898e+09  9.770983e+09         0.0

# %%
# 경기 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193445_경기도_202306-202405_데이터랩_다운로드/20240623193445_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193445_경기도_202306-202405_데이터랩_다운로드/20240623193445_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류       대분류 지출액  대분류 지출액 비율       중분류 지출액  중분류 지출액 비율
# 0      쇼핑업  레저용품쇼핑  3.474086e+09        36.4  4.273682e+08       100.0
# 1      쇼핑업   대형쇼핑몰  3.474086e+09        36.4  3.019280e+09       100.0
# 2      쇼핑업   관광기념품  3.474086e+09        36.4  1.115237e+07       100.0
# 3      쇼핑업     면세점  3.474086e+09        36.4  1.628578e+07       100.0
# 4      숙박업    기타숙박  1.705809e+08         1.8  1.324126e+08       100.0
# 5      숙박업      호텔  1.705809e+08         1.8  2.562076e+07       100.0
# 6      숙박업      콘도  1.705809e+08         1.8  9.319683e+06       100.0
# 7      숙박업  캠핑장/펜션  1.705809e+08         1.8  3.227869e+06       100.0
# 8     식음료업     식음료  4.865576e+09        50.9  4.865576e+09       100.0
# 9   여가서비스업  관광유원시설  9.032624e+08         9.5  2.290853e+07       100.0
# 10  여가서비스업     골프장  9.032624e+08         9.5  6.738919e+08       100.0
# ...

# %% [markdown]
# # 강원 내국인 관광지출액(BC+신한)

# %%
# 강원 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193456_강원특별자치도_202306-202405_데이터랩_다운로드/20240623193456_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193456_강원특별자치도_202306-202405_데이터랩_다운로드/20240623193456_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        기준년월    광역지자체    중분류          지출액      전년도 지출액
# 0    202306  강원특별자치도  관광총소비  116836449.0  126261473.0
# 1    202307  강원특별자치도  관광총소비  130557314.0  147453770.0
# 2    202308  강원특별자치도  관광총소비  152451536.0  167053859.0
# 3    202309  강원특별자치도  관광총소비  110186685.0  114182069.0
# 4    202310  강원특별자치도  관광총소비  123844798.0  135359079.0
# ..      ...      ...    ...          ...          ...
# 229  202405  강원특별자치도    스키장     127659.0     179497.0
# 230  202405  강원특별자치도   육상운송      37076.0      35331.0
# 231  202405  강원특별자치도    면세점      13208.0       8445.0
# 232  202310  강원특별자치도   항공운송        100.0        300.0
# 233  202311  강원특별자치도   항공운송          0.0        200.0
#
# [234 rows x 5 columns]

# %%
# 강원 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193456_강원특별자치도_202306-202405_데이터랩_다운로드/20240623193456_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193456_강원특별자치도_202306-202405_데이터랩_다운로드/20240623193456_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#     광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0  강원특별자치도  1.297813e+09  1.397463e+09         0.0

# %%
# 강원 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193456_강원특별자치도_202306-202405_데이터랩_다운로드/20240623193456_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193456_강원특별자치도_202306-202405_데이터랩_다운로드/20240623193456_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  159829230.0        12.3    3810719.0       100.0
# 1      쇼핑업  레저용품쇼핑  159829230.0        12.3   78521177.0       100.0
# 2      쇼핑업   대형쇼핑몰  159829230.0        12.3   77371045.0       100.0
# 3      쇼핑업     면세점  159829230.0        12.3     126289.0       100.0
# 4      숙박업      호텔  195251556.0        15.0   44000533.0       100.0
# 5      숙박업      콘도  195251556.0        15.0   90684371.0       100.0
# 6      숙박업  캠핑장/펜션  195251556.0        15.0    1635000.0       100.0
# 7      숙박업    기타숙박  195251556.0        15.0   58931652.0       100.0
# 8     식음료업     식음료  735307705.0        56.7  735307705.0       100.0
# 9   여가서비스업  관광유원시설  203898476.0        15.7   11886366.0       100.0
# 10  여가서비스업     골프장  203898476.0        15.7  159617770.0       100.0
# 11  여가서비스업    기타레저  203898476.0        15.7    9403607.0       100.0
# ...

# %% [markdown]
# # 충북 내국인 관광지출액(BC+신한)

# %%
# 충북 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193527_충청북도_202306-202405_데이터랩_다운로드/20240623193527_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193527_충청북도_202306-202405_데이터랩_다운로드/20240623193527_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'GB2312', 'confidence': 0.99, 'language': 'Chinese'}
#        扁霖斥岿 堡开瘤磊眉    吝盒幅          瘤免咀      傈斥档 瘤免咀
# 0    202306  面没合档  包堡醚家厚   94408849.0   93832796.0
# 1    202307  面没合档  包堡醚家厚   87700177.0   96361000.0
# 2    202308  面没合档  包堡醚家厚   89598242.0   94161165.0
# 3    202309  面没合档  包堡醚家厚   91816753.0   94667026.0
# 4    202310  面没合档  包堡醚家厚  100128015.0  107996694.0
# ..      ...   ...    ...          ...          ...
# 223  202402  面没合档   腊惑款价        770.0         74.0
# 224  202403  面没合档   腊惑款价       3367.0       3515.0
# 225  202404  面没合档    坊磐墨      24952.0      23283.0
# 226  202404  面没合档   腊惑款价       4661.0       4292.0
# 227  202405  面没合档   腊惑款价       5204.0       3192.0
#
# [228 rows x 5 columns]

# %%
# 충북 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193527_충청북도_202306-202405_데이터랩_다운로드/20240623193527_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193527_충청북도_202306-202405_데이터랩_다운로드/20240623193527_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0   충청북도  1.043422e+09  1.085256e+09         0.0

# %%
# 충북 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193527_충청북도_202306-202405_데이터랩_다운로드/20240623193527_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193527_충청북도_202306-202405_데이터랩_다운로드/20240623193527_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  221514515.0        21.2    1527854.0       100.0
# 1      쇼핑업  레저용품쇼핑  221514515.0        21.2   70611128.0       100.0
# 2      쇼핑업   대형쇼핑몰  221514515.0        21.2  148722207.0       100.0
# 3      쇼핑업     면세점  221514515.0        21.2     653326.0       100.0
# 4      숙박업  캠핑장/펜션   39494398.0         3.8     301568.0       100.0
# 5      숙박업    기타숙박   39494398.0         3.8   22439716.0       100.0
# 6      숙박업      호텔   39494398.0         3.8    2876802.0       100.0
# 7      숙박업      콘도   39494398.0         3.8   13876312.0       100.0
# 8     식음료업     식음료  611682061.0        58.6  611682061.0       100.0
# 9   여가서비스업  관광유원시설  168808233.0        16.2    3208126.0       100.0
# 10  여가서비스업     골프장  168808233.0        16.2  150915429.0       100.0
# 11  여가서비스업    기타레저  168808233.0        16.2    6940923.0       100.0
# ...

# %% [markdown]
# # 충남 내국인 관광지출액(BC+신한)

# %%
# 충남 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193535_충청남도_202306-202405_데이터랩_다운로드/20240623193535_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193535_충청남도_202306-202405_데이터랩_다운로드/20240623193535_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        기준년월 광역지자체    중분류          지출액      전년도 지출액
# 0    202306  충청남도  관광총소비  106370321.0  106848607.0
# 1    202307  충청남도  관광총소비  102344881.0  107225383.0
# 2    202308  충청남도  관광총소비  105375741.0  107404111.0
# 3    202309  충청남도  관광총소비  104966120.0  104880722.0
# 4    202310  충청남도  관광총소비  111909808.0  120126396.0
# ..      ...   ...    ...          ...          ...
# 199  202307  충청남도    렌터카       9255.0      11695.0
# 200  202308  충청남도    렌터카      21060.0      24785.0
# 201  202309  충청남도    렌터카      11464.0      20392.0
# 202  202310  충청남도    렌터카      28364.0      10516.0
# 203  202312  충청남도    렌터카      16453.0      20006.0
#
# [204 rows x 5 columns]

# %%
# 충남 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193535_충청남도_202306-202405_데이터랩_다운로드/20240623193535_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193535_충청남도_202306-202405_데이터랩_다운로드/20240623193535_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0   충청남도  1.202400e+09  1.232619e+09         0.0

# %%
# 충남 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193535_충청남도_202306-202405_데이터랩_다운로드/20240623193535_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193535_충청남도_202306-202405_데이터랩_다운로드/20240623193535_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  296689566.0        24.7    1995746.0       100.0
# 1      쇼핑업  레저용품쇼핑  296689566.0        24.7   87537827.0       100.0
# 2      쇼핑업   대형쇼핑몰  296689566.0        24.7  207155993.0       100.0
# 3      숙박업      호텔   63957357.0         5.3    6569250.0       100.0
# 4      숙박업      콘도   63957357.0         5.3   22720389.0       100.0
# 5      숙박업  캠핑장/펜션   63957357.0         5.3    1272993.0       100.0
# 6      숙박업    기타숙박   63957357.0         5.3   33394725.0       100.0
# 7     식음료업     식음료  747540446.0        62.2  747540446.0       100.0
# 8   여가서비스업  관광유원시설   93247996.0         7.8    1988043.0       100.0
# 9   여가서비스업     골프장   93247996.0         7.8   73348887.0       100.0
# 10  여가서비스업    기타레저   93247996.0         7.8   10309261.0       100.0
# 11  여가서비스업   문화서비스   93247996.0         7.8    7601805.0       100.0
# ...

# %% [markdown]
# # 전북 내국인 관광지출액(BC+신한)

# %%
# 전북 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193545_전북특별자치도_202306-202405_데이터랩_다운로드/20240623193545_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193545_전북특별자치도_202306-202405_데이터랩_다운로드/20240623193545_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.882604970008569, 'language': 'Korean'}
#        기준년월    광역지자체    중분류         지출액     전년도 지출액
# 0    202306  전북특별자치도  관광총소비  60892484.0  74398947.0
# 1    202307  전북특별자치도  관광총소비  58266540.0  73797032.0
# 2    202308  전북특별자치도  관광총소비  61601208.0  74322851.0
# 3    202309  전북특별자치도  관광총소비  62486974.0  62819767.0
# 4    202310  전북특별자치도  관광총소비  68554025.0  72478013.0
# ..      ...      ...    ...         ...         ...
# 215  202401  전북특별자치도   육상운송        35.0       239.0
# 216  202402  전북특별자치도   육상운송       261.0      3285.0
# 217  202403  전북특별자치도   육상운송       526.0      1485.0
# 218  202404  전북특별자치도   육상운송      4064.0      1246.0
# 219  202405  전북특별자치도   육상운송      2867.0      2203.0
#
# [220 rows x 5 columns]

# %%
# 전북 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193545_전북특별자치도_202306-202405_데이터랩_다운로드/20240623193545_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193545_전북특별자치도_202306-202405_데이터랩_다운로드/20240623193545_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#     광역지자체명          소비액     전년동기 소비액  전년대비 소비증감률
# 0  전북특별자치도  723821302.0  772893307.0         0.0

# %%
# 전북 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193545_전북특별자치도_202306-202405_데이터랩_다운로드/20240623193545_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193545_전북특별자치도_202306-202405_데이터랩_다운로드/20240623193545_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  153849882.0        21.3    1729415.0       100.0
# 1      쇼핑업  레저용품쇼핑  153849882.0        21.3   63919096.0       100.0
# 2      쇼핑업   대형쇼핑몰  153849882.0        21.3   88199145.0       100.0
# 3      쇼핑업     면세점  153849882.0        21.3       2226.0       100.0
# 4      숙박업      호텔   37940520.0         5.2    1098066.0       100.0
# 5      숙박업    기타숙박   37940520.0         5.2   24969251.0       100.0
# 6      숙박업  캠핑장/펜션   37940520.0         5.2     346873.0       100.0
# 7      숙박업      콘도   37940520.0         5.2   11526330.0       100.0
# 8     식음료업     식음료  452391114.0        62.5  452391114.0       100.0
# 9   여가서비스업  관광유원시설   72595457.0        10.0    1641524.0       100.0
# 10  여가서비스업     골프장   72595457.0        10.0   59951443.0       100.0
# 11  여가서비스업    기타레저   72595457.0        10.0    5169381.0       100.0
# ...

# %% [markdown]
# # 전남 내국인 관광지출액(BC+신한)

# %%
# 전남 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193603_전라남도_202306-202405_데이터랩_다운로드/20240623193603_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193603_전라남도_202306-202405_데이터랩_다운로드/20240623193603_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        기준년월 광역지자체     중분류         지출액      전년도 지출액
# 0    202306  전라남도   관광총소비  86029853.0   87898368.0
# 1    202307  전라남도   관광총소비  85423138.0   92480100.0
# 2    202308  전라남도   관광총소비  93242223.0  100090911.0
# 3    202309  전라남도   관광총소비  82391838.0   81307485.0
# 4    202310  전라남도   관광총소비  95731243.0   98444966.0
# ..      ...   ...     ...         ...          ...
# 215  202405  전라남도      콘도    851687.0     950907.0
# 216  202405  전라남도  캠핑장/펜션     74216.0      73850.0
# 217  202405  전라남도     여행업     85874.0      79558.0
# 218  202405  전라남도    육상운송      5357.0      11126.0
# 219  202405  전라남도     면세점     39158.0      13115.0
#
# [220 rows x 5 columns]

# %%
# 전남 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193603_전라남도_202306-202405_데이터랩_다운로드/20240623193603_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193603_전라남도_202306-202405_데이터랩_다운로드/20240623193603_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명          소비액      전년동기 소비액  전년대비 소비증감률
# 0   전라남도  985408757.0  1.011227e+09         0.0

# %%
# 전남 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193603_전라남도_202306-202405_데이터랩_다운로드/20240623193603_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193603_전라남도_202306-202405_데이터랩_다운로드/20240623193603_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  174988859.0        17.8    2456259.0       100.0
# 1      쇼핑업  레저용품쇼핑  174988859.0        17.8   64338556.0       100.0
# 2      쇼핑업   대형쇼핑몰  174988859.0        17.8  107710683.0       100.0
# 3      쇼핑업     면세점  174988859.0        17.8     483360.0       100.0
# 4      숙박업      호텔   66994498.0         6.8    5483044.0       100.0
# 5      숙박업    기타숙박   66994498.0         6.8   48598309.0       100.0
# 6      숙박업      콘도   66994498.0         6.8   12098980.0       100.0
# 7      숙박업  캠핑장/펜션   66994498.0         6.8     814165.0       100.0
# 8     식음료업     식음료  591318424.0        60.0  591318424.0       100.0
# 9   여가서비스업  관광유원시설  150051220.0        15.2   15514328.0       100.0
# 10  여가서비스업     골프장  150051220.0        15.2  116746594.0       100.0
# 11  여가서비스업    기타레저  150051220.0        15.2    7954448.0       100.0
# ...

# %% [markdown]
# # 경북 내국인 관광지출액(BC+신한)

# %%
# 경북 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193610_경상북도_202306-202405_데이터랩_다운로드/20240623193610_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193610_경상북도_202306-202405_데이터랩_다운로드/20240623193610_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.5773011617515639, 'language': 'Korean'}
#        기준년월 광역지자체    중분류          지출액      전년도 지출액
# 0    202306  경상북도  관광총소비  110459191.0  113016718.0
# 1    202307  경상북도  관광총소비  110242168.0  116574936.0
# 2    202308  경상북도  관광총소비  113522269.0  121930039.0
# 3    202309  경상북도  관광총소비  108406519.0  105746570.0
# 4    202310  경상북도  관광총소비  119804162.0  127817641.0
# ..      ...   ...    ...          ...          ...
# 199  202405  경상북도  문화서비스     701688.0     757700.0
# 200  202405  경상북도    식음료   68852251.0   71015867.0
# 201  202405  경상북도     콘도    1253162.0    1397577.0
# 202  202405  경상북도    여행업      64735.0      43815.0
# 203  202405  경상북도   육상운송      11760.0       3623.0
#
# [204 rows x 5 columns]

# %%
# 경북 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193610_경상북도_202306-202405_데이터랩_다운로드/20240623193610_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193610_경상북도_202306-202405_데이터랩_다운로드/20240623193610_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0   경상북도  1.266041e+09  1.311369e+09         0.0

# %%
# 경북 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193610_경상북도_202306-202405_데이터랩_다운로드/20240623193610_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193610_경상북도_202306-202405_데이터랩_다운로드/20240623193610_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  221180594.0        17.5    3704295.0       100.0
# 1      쇼핑업  레저용품쇼핑  221180594.0        17.5  103727450.0       100.0
# 2      쇼핑업   대형쇼핑몰  221180594.0        17.5  113748849.0       100.0
# 3      숙박업      호텔   69272559.0         5.5   17294193.0       100.0
# 4      숙박업  캠핑장/펜션   69272559.0         5.5    1431476.0       100.0
# 5      숙박업    기타숙박   69272559.0         5.5   35224729.0       100.0
# 6      숙박업      콘도   69272559.0         5.5   15322161.0       100.0
# 7     식음료업     식음료  783320538.0        61.9  783320538.0       100.0
# 8   여가서비스업  관광유원시설  190295524.0        15.0    2890247.0       100.0
# 9   여가서비스업     골프장  190295524.0        15.0  166276036.0       100.0
# 10  여가서비스업    기타레저  190295524.0        15.0   12976401.0       100.0
# 11  여가서비스업   문화서비스  190295524.0        15.0    8152841.0       100.0
# ...

# %% [markdown]
# # 경남 내국인 관광지출액(BC+신한)

# %%
# 경남 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193617_경상남도_202306-202405_데이터랩_다운로드/20240623193617_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193617_경상남도_202306-202405_데이터랩_다운로드/20240623193617_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        기준년월 광역지자체    중분류          지출액      전년도 지출액
# 0    202306  경상남도  관광총소비  133149262.0  136956513.0
# 1    202307  경상남도  관광총소비  134375565.0  140972200.0
# 2    202308  경상남도  관광총소비  134134741.0  144243789.0
# 3    202309  경상남도  관광총소비  131609547.0  128068472.0
# 4    202310  경상남도  관광총소비  142734862.0  151467351.0
# ..      ...   ...    ...          ...          ...
# 214  202401  경상남도    면세점        550.0        302.0
# 215  202402  경상남도    면세점        475.0        372.0
# 216  202403  경상남도    면세점        318.0        845.0
# 217  202404  경상남도    면세점        388.0        480.0
# 218  202405  경상남도    면세점        546.0        446.0
#
# [219 rows x 5 columns]

# %%
# 경남 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193617_경상남도_202306-202405_데이터랩_다운로드/20240623193617_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193617_경상남도_202306-202405_데이터랩_다운로드/20240623193617_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#   광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0   경상남도  1.561888e+09  1.599574e+09         0.0

# %%
# 경남 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193617_경상남도_202306-202405_데이터랩_다운로드/20240623193617_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193617_경상남도_202306-202405_데이터랩_다운로드/20240623193617_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  376769685.0        24.1    3778965.0       100.0
# 1      쇼핑업  레저용품쇼핑  376769685.0        24.1  107215686.0       100.0
# 2      쇼핑업   대형쇼핑몰  376769685.0        24.1  265769573.0       100.0
# 3      쇼핑업     면세점  376769685.0        24.1       5462.0       100.0
# 4      숙박업    기타숙박   62266545.0         4.0   40164236.0       100.0
# 5      숙박업      호텔   62266545.0         4.0    5760170.0       100.0
# 6      숙박업      콘도   62266545.0         4.0   15070039.0       100.0
# 7      숙박업  캠핑장/펜션   62266545.0         4.0    1272099.0       100.0
# 8     식음료업     식음료  918013526.0        58.8  918013526.0       100.0
# 9   여가서비스업  관광유원시설  201255634.0        12.9    4849956.0       100.0
# 10  여가서비스업     골프장  201255634.0        12.9  169016850.0       100.0
# 11  여가서비스업    기타레저  201255634.0        12.9   14490039.0       100.0
# ...

# %% [markdown]
# # 제주 내국인 관광지출액(BC+신한)

# %%
# 제주 관광소비 추이

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193628_제주특별자치도_202306-202405_데이터랩_다운로드/20240623193628_관광소비 추이.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193628_제주특별자치도_202306-202405_데이터랩_다운로드/20240623193628_관광소비 추이.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        기준년월    광역지자체    중분류          지출액      전년도 지출액
# 0    202306  제주특별자치도  관광총소비   96518204.0  119576935.0
# 1    202307  제주특별자치도  관광총소비   91258661.0  114248529.0
# 2    202308  제주특별자치도  관광총소비  102788155.0  124708413.0
# 3    202309  제주특별자치도  관광총소비   81507245.0   90420790.0
# 4    202310  제주특별자치도  관광총소비   92968464.0  113063003.0
# ..      ...      ...    ...          ...          ...
# 224  202401  제주특별자치도   육상운송      12877.0       9311.0
# 225  202402  제주특별자치도   육상운송      14448.0      14000.0
# 226  202403  제주특별자치도   육상운송      15901.0      24629.0
# 227  202404  제주특별자치도   육상운송      18805.0      17307.0
# 228  202405  제주특별자치도   육상운송      21975.0      15119.0
#
# [229 rows x 5 columns]

# %%
# 제주 관광소비 히트맵

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193628_제주특별자치도_202306-202405_데이터랩_다운로드/20240623193628_관광소비 히트맵.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193628_제주특별자치도_202306-202405_데이터랩_다운로드/20240623193628_관광소비 히트맵.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#     광역지자체명           소비액      전년동기 소비액  전년대비 소비증감률
# 0  제주특별자치도  1.000704e+09  1.190406e+09         0.0

# %%
# 제주 업종별 지출액

import pandas as pd
import chardet

# 파일의 인코딩 감지
with open('/content/drive/MyDrive/문체부 공모전/20240623193628_제주특별자치도_202306-202405_데이터랩_다운로드/20240623193628_업종별 지출액.csv', 'rb') as f:
    result = chardet.detect(f.read())

# 인코딩 감지 결과 출력
print(result)

# 감지된 인코딩으로 파일 읽기
data = pd.read_csv('/content/drive/MyDrive/문체부 공모전/20240623193628_제주특별자치도_202306-202405_데이터랩_다운로드/20240623193628_업종별 지출액.csv', encoding=result['encoding'])

# 데이터 확인
data
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업     면세점  254226108.0        25.4  151575557.0       100.0
# 1      쇼핑업   관광기념품  254226108.0        25.4   32275251.0       100.0
# 2      쇼핑업  레저용품쇼핑  254226108.0        25.4   39137777.0       100.0
# 3      쇼핑업   대형쇼핑몰  254226108.0        25.4   31237524.0       100.0
# 4      숙박업      호텔  137954346.0        13.8   58192934.0       100.0
# 5      숙박업      콘도  137954346.0        13.8   38781048.0       100.0
# 6      숙박업  캠핑장/펜션  137954346.0        13.8     467368.0       100.0
# 7      숙박업    기타숙박  137954346.0        13.8   40512996.0       100.0
# 8     식음료업     식음료  434614252.0        43.4  434614252.0       100.0
# 9   여가서비스업  관광유원시설   93411268.0         9.3    8821744.0       100.0
# 10  여가서비스업     골프장   93411268.0         9.3   65741875.0       100.0
# 11  여가서비스업    기타레저   93411268.0         9.3    5566296.0       100.0
# ...
